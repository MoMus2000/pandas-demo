# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
null_rows = len(df.dropna())
actual_rows = len(df)

# %%
print(null_rows)
print(actual_rows)
# Out:
# 183
# 891

# %%
df.dropna(inplace=True)

# %%
df["Age"].hist(bins=10)
# Out:
# <Axes: >

# %%
female_travelers = df.query("Sex == 'female'")
female_survived = female_travelers.query("Survived == 1")
print(f"TOTAL Females THAT SURVIVED {len(female_survived)}")
# Out:
# TOTAL Females THAT SURVIVED 82

# %%
male_travelers = df.query("Sex == 'male'")
# print(male_travelers)
male_survived = male_travelers.query("Survived == 1")
print(f"TOTAL MALES THAT SURVIVED {len(male_survived)}")
# Out:
# TOTAL MALES THAT SURVIVED 41

# %%
male_travelers.describe()
# Out:
#        PassengerId   Survived     Pclass        Age      SibSp      Parch  \
# count    95.000000  95.000000  95.000000  95.000000  95.000000  95.000000
# mean    449.389474   0.431579   1.168421  38.451789   0.400000   0.410526
# std     247.645177   0.497924   0.497924  16.429746   0.590708   0.750811
# min       7.000000   0.000000   1.000000   0.920000   0.000000   0.000000
# 25%     247.500000   0.000000   1.000000  28.000000   0.000000   0.000000
# 50%     457.000000   0.000000   1.000000  37.000000   0.000000   0.000000
# 75%     667.500000   1.000000   1.000000  49.000000   1.000000   1.000000
# max     890.000000   1.000000   3.000000  80.000000   3.000000   4.000000
#
#              Fare
# count   95.000000
# mean    69.124343
# std     83.008379
# min      0.000000
# 25%     27.150000
# 50%     51.862500
# 75%     79.200000
# max    512.329200

# %%
male_travelers["Age"].hist(bins=10)
# Out:
# <Axes: >

# %%
male_survived["Age"].hist(bins=10)
# Out:
# <Axes: >

# %%
male_survived[["Survived", "Pclass", "Age"]].groupby('Pclass')['Survived'].sum()
# Out:
# Pclass
# 1    35
# 2     4
# 3     2
# Name: Survived, dtype: int64

# %%
female_survived[["Survived", "Pclass", "Age"]].groupby('Pclass')['Survived'].sum()
# Out:
# Pclass
# 1    71
# 2     8
# 3     3
# Name: Survived, dtype: int64

# %%
male_survived.to_csv("male_survival_data", index=False)

# %%
female_survived.to_csv("female_survival_data", index=False)
